# %%
import pandas as pd 
import dask.dataframe as dd 
import time
import memory_profiler

# %%
pip install memory_profiler
# Out:
# ...
#
# ...

# %%
pandas_df = pd.read_csv(r"E:\Data Engineering - ITI\Python Libraries\Final Project\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
pandas_df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21964\1138233948.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   pandas_df = pd.read_csv(r"E:\Data Engineering - ITI\Python Libraries\Final Project\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# ...

# %%
dask_df = dd.read_csv(r"E:\Data Engineering - ITI\Python Libraries\Final Project\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
dask_df
# Out:
# Dask DataFrame Structure:
# ...

# %%
  def calculate_attacks_per_year(df):
    start_time = time.time()
    attacks_per_year = pandas_df.groupby(['country', 'iyear'])['attacktype1_txt'].count().reset_index(name='nkill')
    end_time = time.time()
    time_difference = end_time - start_time
    return attacks_per_year, time_difference

pandas_result, pandas_time = calculate_attacks_per_year(pandas_df)
dask_result, dask_time = calculate_attacks_per_year(dask_df)

print("Pandas time:", pandas_time)
print("Dask time:", dask_time)
# Out:
# Pandas time: 1.857210636138916
# Dask time: 0.06690168380737305

# %%
print(pandas_df.memory_usage(deep=True).sum())
# Out:
# 629793801

# %%
start_time = time.time()
end_time = time.time()
time_difference = end_time - start_time
result = dask_df.compute()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\dask\dataframe\io\csv.py:195: DtypeWarning: Columns (61,62,63,79,114,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 4
#       2 end_time = time.time()
#       3 time_difference = end_time - start_time
# ----> 4 result = dask_df.compute()
#
# File ~\anaconda3\Lib\site-packages\dask_expr\_collection.py:476, in FrameBase.compute(self, fuse, **kwargs)
#     474     out = out.repartition(npartitions=1)
#     475 out = out.optimize(fuse=fuse)
# --> 476 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\dask\base.py:375, in DaskMethodsMixin.compute(self, **kwargs)
#     351 def compute(self, **kwargs):
#     352     """Compute this dask collection
#     353
# ...

# %%
print(pandas_df.memory_usage(deep=True) )
print(dask_df.memory_usage(deep=True) )
#df['object'].astype('category').memory_usage(deep=True)

# %%
pandas_memory_usage=memory_profiler.memory_usage()
df = pd.read_csv(r"E:\Data Engineering - ITI\Python Libraries\Final Project\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
print(f"Pandas memory usage: {pandas_memory_usage}")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21964\2304748419.py:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"E:\Data Engineering - ITI\Python Libraries\Final Project\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
# Pandas memory usage: [1404.12109375]

# %%
dask_memory_usage=pandas_memory_usage=memory_profiler.memory_usage()[0]
dask_df=dd.read_csv(r"E:\Data Engineering - ITI\Python Libraries\Final Project\globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
print(f"Dask memory usage: {dask_memory_usage}")
